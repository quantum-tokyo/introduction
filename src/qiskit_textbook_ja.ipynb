# %% [markdown]
# # Qiskitテキストブック 日本語版
#
# ## Qiskit を使った量子計算の学習
#
# 0. 前提条件</br>
# 0.1 [Qiskitテキストブックで作業するための環境設定ガイド](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-prerequisites/setting-the-environment.ipynb)</br>
# 0.2 [Python 及び Jupyter notebook 入門](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-prerequisites/python-and-jupyter-notebooks.ipynb)
#
# 1. 量子状態と量子ビット</br>
# 1.1 [はじめに](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-states/introduction.ipynb) </br>
# 1.2 [計算の原子](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-states/atoms-computation.ipynb)</br>
# 1.3 [量子ビット状態を表現する](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-states/representing-qubit-states.ipynb)</br>
# 1.4 [単一量子ビットゲート](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-states/single-qubit-gates.ipynb)</br>
# 1.5 [量子コンピューターの場合](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-states/case-for-quantum.ipynb)</br>
#
# 2. 複数量子ビットともつれ状態<br>
# 2.1 [はじめに](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-gates/introduction.ipynb)<br>
# 2.2 [複数量子ビットともつれ状態](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-gates/multiple-qubits-entangled-states.ipynb)<br>
# 2.3 [位相キックバック](https://github.com/Qiskit/textbook/blob/main/translations/ja/algorithms/phase-kickback.ipynb)<br>
# 2.4 [基本的な回路の等価性](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-gates/more-circuit-identities.ipynb)<br>
# 2.5 [普遍性の証明](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-gates/proving-universality.ipynb)<br>
# 2.6 [量子コンピューター上の古典計算](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-gates/oracles.ipynb)<br>
#
# 3. 量子プロトコルと量子アルゴリズム<br>
# 3.1 [量子回路](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/defining-quantum-circuits.ipynb)<br>
# 3.2 [ドイチ-ジョサのアルゴリズム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/deutsch-jozsa.ipynb)<br>
# 3.3 [ベルンシュタイン・ヴァジラニ アルゴリズム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/bernstein-vazirani.ipynb)<br>
# 3.4 [サイモンのアルゴリズム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/simon.ipynb)<br>
# 3.5 [量子フーリエ変換](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/quantum-fourier-transform.ipynb)<br>
# 3.6 [量子位相推定](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/quantum-phase-estimation.ipynb)<br>
# 3.7 [ショアのアルゴリズム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/shor.ipynb)<br>
# 3.8 [グローバーのアルゴリズム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/grover.ipynb)<br>
# 3.9 [量子数え上げ](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/quantum-counting.ipynb)<br>
# 3.10 [量子ウォークによる探索アルゴリズム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/quantum-walk-search-algorithm.ipynb)<br>
# 3.11 [隠れシフト問題（未翻訳）](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-algorithms/hidden-shift-problem.ipynb)<br>
# 3.12 [量子鍵配送](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/quantum-key-distribution.ipynb)<br>
# 3.13 [超密度符号化](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/superdense-coding.ipynb)<br>
# 3.14 [量子テレポーテーション](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-algorithms/teleportation.ipynb)<br>
#
# 4. 量子アプリケーションのアルゴリズム<br>
# 4.1 [HHL を利用して線形方程式系を解きQiskit で実装する](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-applications/hhl_tutorial.ipynb)<br>
# 4.2 [VQEを利用した分子シミュレーション](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-applications/vqe-molecules.ipynb)<br>
# 4.3 [QAOA を利用して、組合せ最適化問題を解く](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-applications/qaoa.ipynb)<br>
# 4.4 [Groverのアルゴリズムを用いた充足可能性問題の解法](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-applications/satisfiability-grover.ipynb)<br>
# 4.5 [PyTorchとQiskitを用いた量子古典ハイブリッド・ニューラル・ネットワーク](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-machine-learning/machine-learning-qiskit-pytorch.ipynb)<br>
# 4.6 [量子画像の柔軟な表現（FRQI）](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-applications/image-processing-frqi-neqr.ipynb)<br>
# 4.7 [量子顔表情認識](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-applications/facial-expression-recognition.ipynb)<br>
# 4.8 [Quantum edge detection (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-applications/quantum-edge-detection.ipynb)<br>
# 4.9 [Travelling Salesman Problem using Quantum Phase Estimation (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-applications/tsp.ipynb)<br>
# 4.10 [量子変分線型ソルバー（Valiational Quantum Linear Solver)](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-paper-implementations/vqls.ipynb)<br>
#
#
#
#
# 5. 量子回路による量子ハードウェアの探求<br>
# 5.1 [反復符号による量子エラー訂正の導入](https://github.com/Qiskit/textbook/blob/main/translations/ja/quantum-hardware/error-correction-repetition-code.ipynb)<br>
# 5.2 [測定エラーの軽減](https://github.com/Qiskit/textbook/blob/main/translations/ja/quantum-hardware/measurement-error-mitigation.ipynb)<br>
# 5.3 [ランダマイズド・ベンチマーキング](https://github.com/Qiskit/textbook/blob/main/translations/ja/quantum-hardware/randomized-benchmarking.ipynb)<br>
# 5.4 [量子ボリュームの測定](https://github.com/Qiskit/textbook/blob/main/translations/ja/quantum-hardware/measuring-quantum-volume.ipynb)<br>
# 5.5 [密度行列と混合状態](https://github.com/Qiskit/textbook/blob/main/translations/ja/quantum-hardware/density-matrix.ipynb)<br>
#
#
# 6. マイクロ波パルスによる量子ハードウェアの探求<br>
# 6.1 [Qiskit Pulseで量子ビットを較正する](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-quantum-hardware/calibrating-qubits-pulse.ipynb)<br>
# 6.2 [Qiskit Pulseで高エネルギー状態へアクセスする](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-quantum-hardware/accessing_higher_energy_states.ipynb)<br>
# 6.3 [トランズモン物理入門](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-quantum-hardware/transmon-physics.ipynb)<br>
# 6.4 [回路量子電磁力学](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-quantum-hardware/cQED-JC-SW.ipynb)<br>
# 6.5 [Qiskit Pulseを用いたJaynes-Cummingsハミルトニアンの探究](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-quantum-hardware/Jaynes-Cummings-model.ipynb)<br>
# 6.6 [Measuring the Qubit ac-Stark Shift (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/quantum-hardware-pulses/ac-Stark-shift.ipynb)<br>
# 6.7 [Hamiltonian Tomography (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/quantum-hardware-pulses/hamiltonian-tomography.ipynb)
#
# 7. 練習問題<br>
# 7.1 [ラボ1 量子回路](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-labs/Lab01_QuantumCircuits.ipynb)<br>
# 7.2 [ラボ2 単一量子ビットゲート](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-labs/Lab02_Single_Qubit_Gates.ipynb)<br>
# 7.3 [ラボ3 量子測定](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-labs/Lab03_QuantumMeasurement.ipynb)<br>
# 7.4 [ラボ4 ベル回路とGHZ回路](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-labs/Lab04_Bell_GHZ_Circuit.ipynb)<br>
# 7.5 [Lab 5 Accuracy of Quantum Phase Estimation (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-labs/Lab05_AccuracyQPE.ipynb)<br>
# 7.6 [Lab 6 Iterative Phase Estimation Algorithm (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-labs/Lab05_AccuracyQPE.ipynb)<br>
# 7.7 [Lab 7 Scalable Shor’s Algorithm (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-labs/Lab07_Scalable_Shor_Algorithm.ipynb)<br>
# 7.8 [Lab 8 Grover’s search with an unknown number of solutions (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-labs/Lab08_Grover_search_with_an_unknown_number_of_solutions.ipynb)<br>
# 7.9 [ラボ9 検索アルゴリズムとしての量子シミュレーション](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-labs/Lab09_QuantumSimulationSearchAlgorithm.ipynb)<br>
# 7.10 [Lab 10 Quantum Error Correction (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-labs/Lab10_QEC.ipynb)
#
# 8. 付録<br>
# 8.1 [量子コンピューティング向け線形代数入門](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-appendix/linear_algebra.ipynb)<br>
# 8.2 [Qiskitの文法の基礎](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-appendix/qiskit.ipynb)<br>
#
# 9. ゲームとデモ<br>
# 9.1 [こんにちはQiskitゲーム](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-ex/hello-qiskit.ipynb)<br>
# 9.2 [量子位相推定を使った円周率の推定](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-demos/piday-code.ipynb)<br>
# 9.3 [局所実在論とCHSH不等式](https://github.com/Qiskit/textbook/blob/main/translations/ja/ch-demos/chsh.ipynb)<br>
# 9.4 [Quantum Coin Game (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-demos/coin-game.ipynb)<br>
# 9.5 [Variational Quantum Regression (未翻訳)](https://github.com/Qiskit/textbook/blob/main/notebooks/ch-demos/variational-quantum-regression.ipynb)
