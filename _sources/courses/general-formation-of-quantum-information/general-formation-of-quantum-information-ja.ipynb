# %% [markdown]
# # 量子情報の一般的定式化
#
# [General formulation of quantum information](https://quantum.cloud.ibm.com/learning/ja/courses/general-formulation-of-quantum-information)
#
# **密度行列**
# [はじめに](./density-matrices/introduction-ja.ipynb)
# １. [密度行列の基礎](./density-matrices/density-matrix-basics-ja.ipynb) ([解説スライド](./density-matrices/1_density_matirx_basics.pdf))
# 2. [密度行列の凸結合](./density-matrices/convex-combinations-ja.ipynb)([解説スライド](./density-matrices/2_convex_combinations.pdf))
# 3. [ブロッホ球](./density-matrices/bloch-sphere-ja.ipynb)([解説スライド](./density-matrices/3_bloch_sphere.pdf))
# 4. [複数システムと縮約状態](./density-matrices/multiple-systems-ja.ipynb)([解説スライド](./density-matrices/4_multiple_systems.pdf))
#
# **量子チャネル**
# [はじめに](./quantum-channels/introduction-ja.ipynb)
# 5. [量子チャネルの基礎](./quantum-channels/quantum-channel-basics-ja.ipynb)([解説スライド](./quantum-channels/5_quantum-channel-basics.pdf))
# 6. [チャネルの表現](./quantum-channels/representations-of-channels-ja.ipynb)([解説スライド](./quantum-channels/6_representations-of-channels.pdf))
# 7. [表現の等価性](./quantum-channels/representation-equivalence-ja.ipynb)
#
# **一般的な測定**
# はじめに
# 8. 測定の数学的定式化
# 9. ナイマルクの定理
# 10. 量子状態の識別とトモグラフィー
#
# **純粋化と忠実度**
# はじめに
# 11. 純粋化
# 12. 忠実度
