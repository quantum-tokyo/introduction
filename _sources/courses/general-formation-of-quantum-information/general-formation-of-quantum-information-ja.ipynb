# %% [markdown]
# # 量子情報の一般的定式化
# General formulation of quantum information
#
# source: https://quantum.cloud.ibm.com/learning/ja/courses/general-formulation-of-quantum-information
#
# 密度行列
# [はじめに](./density-matrices/introduction-ja.ipynb)
# 1. [密度行列の基礎](./density-matrices/density-matrix-basics-ja.ipynb) ([解説スライド](./density-matrices/1_density_matirx_basics.pdf))
# 2. [密度行列の凸結合](./density-matrices/convex-combinations-ja.ipynb)
# 3. [ブロッホ球](./density-matrices/bloch-sphere-ja.ipynb)
# 4.  複数システムと縮約状態
#
# 量子チャネル
# はじめに
# 6. 量子チャネルの基礎
# 7. チャネルの表現
# 8. 表現の等価性
#
# 一般的な測定
# はじめに
# 9. 測定の数学的定式化
# 10. ナイマルクの定理
# 11. 量子状態の識別とトモグラフィー
#
# 純粋化と忠実度
# はじめに
# 12. 純粋化
# 13. 忠実度
